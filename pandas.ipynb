# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
# help(pd.Series)

# %%
data = [1776, 1867, 1821]
index = ["USA", "Canada", "Mexico"]

# %%
series = pd.Series(data=data, index=index)

# %%
series
# Out:
# USA       1776
# Canada    1867
# Mexico    1821
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series['USA']
# Out:
# 1776

# %%
ages = { 'Kin': 49, 'Karen': 36, 'Kennie': 50 }
age_series = pd.Series(ages)
age_series
# Out:
# Kin       49
# Karen     36
# Kennie    50
# dtype: int64

# %%
# TASK: Use pandas to grab the expenses paid by Bob.
# MAKE SURE TO READ THE FULL INSTRUCTIONS ABOVE CAREFULLY, AS THE EVALUATION SCRIPT IS VERY STRICT.

import pandas as pd
expenses = pd.Series({'Andrew':200,'Bob':150,'Claire':450})

bob_expense = expenses['Bob']
bob_expense
# Out:
# 150

# %%
# Imaginary Sales Data for 1st and 2nd Quarters for Global Company
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA': 260}

# %%
sales_q1 = pd.Series(q1)
sales_q2 = pd.Series(q2)

# %%
sales_q1 + sales_q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
sales_q1.add(sales_q2, fill_value=0)
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %%
np.random.seed(101)
data = np.random.randint(0, 101,(4,3))
data
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
index = ['CA', 'NY', 'AZ', 'TX']
columns = ['Jan', 'Feb', 'Mar']
df = pd.DataFrame(data = data, index=index, columns=columns)
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int64
#  1   Feb     4 non-null      int64
#  2   Mar     4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %%
pwd
# Out:
# '/Users/kinwong/dev/github/udemy-ml-masterclass'

# %%
ls
# Out:
# README.md         numpy.ipynb       playground.ipynb
# notebooks_final/  pandas.ipynb      requirements.txt

# %%
df = pd.read_csv('notebooks_final/03-Pandas/tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# Column

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %%
df[['total_bill', 'Payer Name']]
# Out:
#      total_bill          Payer Name
# 0         16.99  Christy Cunningham
# 1         10.34      Douglas Tucker
# 2         21.01      Travis Walters
# 3         23.68    Nathaniel Harris
# 4         24.59        Tonya Carter
# ..          ...                 ...
# 239       29.03       Michael Avila
# 240       27.18      Monica Sanders
# 241       22.67          Keith Wong
# 242       17.82        Dennis Dixon
# 243       18.78     Michelle Hardin
#
# [244 rows x 2 columns]

# %%
df['tip_percentage'] = np.round(df['tip'] / df['total_bill'] * 100, 2)
df['tip_percentage']
# Out:
# 0       5.94
# 1      16.05
# 2      16.66
# 3      13.98
# 4      14.68
#        ...
# 239    20.39
# 240     7.36
# 241     8.82
# 242     9.82
# 243    15.97
# Name: tip_percentage, Length: 244, dtype: float64

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
df = df.drop('tip_percentage', axis=1)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df = df.set_index('Payment ID')
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df.iloc[0:3]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322

# %%
df.loc[['Sun2959', 'Sun4458']]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4458                 7.00      Travis Walters  6011812112971322

# %%
df.drop('Sun2959')
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# ...

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df = pd.read_csv('./notebooks_final/03-Pandas/tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df[(df['total_bill'] > 40) & (df['sex'] == 'Male')]
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 95        40.17   4.73  Male    Yes   Fri  Dinner     4             10.04
# 142       41.19   5.00  Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00  Male     No   Sun  Dinner     6              8.03
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3             16.94
# 182       45.35   3.50  Male    Yes   Sun  Dinner     3             15.12
# 184       40.55   3.00  Male    Yes   Sun  Dinner     2             20.27
# 212       48.33   9.00  Male     No   Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 59       Brian Ortiz  6596453823950595    Sat8139
# 95     Aaron Bentley   180026611638690    Fri9628
# 142     Eric Andrews  4356531761046453   Thur3621
# 156    Ryan Gonzales  3523151482063321    Sun7518
# ...

# %%
df[df['day'].isin(['Sun', 'Sat'])]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
last_four = lambda num: str(num)[-4:]

# %%
last_four(1234567)
# Out:
# '4567'

# %%
df['last_four'] = df['CC Number'].apply(last_four)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four
# 0  Christy Cunningham  3560325168603410    Sun2959      3410
# 1      Douglas Tucker  4478071379779230    Sun4608      9230
# 2      Travis Walters  6011812112971322    Sun4458      1322
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994
# 4        Tonya Carter  4832732618637221    Sun2251      7221

# %%
import timeit 
  
# code snippet to be executed only once 
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('./notebooks_final/03-Pandas/tips.csv')
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"
'''
  
# code snippet whose execution time is to be measured 
stmt_one = ''' 
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
'''

stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_one, 
                    number = 1000)
# Out:
# 1.9506079999996473

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_two, 
                    number = 1000)
# Out:
# 0.19833708399983152

# %%
df = pd.read_csv('./notebooks_final/03-Pandas/tips.csv')

# %%
df.sort_values('tip', ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df = pd.read_csv('./notebooks_final/03-Pandas/movie_scores.csv')
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df.isnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0       False      False  False  False            False             False
# 1        True       True   True   True             True              True
# 2       False      False  False  False             True              True
# 3       False      False  False  False            False             False
# 4       False      False  False  False            False             False

# %%
df[df['pre_movie_score'].isnull()]
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN

# %%
df.dropna()
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
# help(df.fillna)
df['pre_movie_score'] = df['pre_movie_score'].fillna(0)
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              0.0               NaN
# 2       Hugh   Jackman  51.0    m              0.0               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df = pd.read_csv('./notebooks_final/03-Pandas/mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
year_cylinder = df.groupby(['model_year', 'cylinders']).mean()
year_cylinder
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
year_cylinder.index.levels
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [3, 4, 5, 6, 8]])

# %%
df.groupby('model_year').describe()
# Out:
#              mpg                                                          \
#            count       mean       std   min     25%    50%     75%   max
# model_year
# 70          29.0  17.689655  5.339231   9.0  14.000  16.00  22.000  27.0
# 71          28.0  21.250000  6.591942  12.0  15.500  19.00  27.000  35.0
# 72          28.0  18.714286  5.435529  11.0  13.750  18.50  23.000  28.0
# 73          40.0  17.100000  4.700245  11.0  13.000  16.00  20.000  29.0
# 74          27.0  22.703704  6.420010  13.0  16.000  24.00  27.000  32.0
# 75          30.0  20.266667  4.940566  13.0  16.000  19.50  23.000  33.0
# 76          34.0  21.573529  5.889297  13.0  16.750  21.00  26.375  33.0
# 77          28.0  23.375000  6.675862  15.0  17.375  21.75  30.000  36.0
# 78          36.0  24.061111  6.898044  16.2  19.350  20.70  28.000  43.1
# 79          29.0  25.093103  6.794217  15.5  19.200  23.90  31.800  37.3
# 80          29.0  33.696552  7.037983  19.1  29.800  32.70  38.100  46.6
# ...

# %%
year_cylinder.loc[70]
# Out:
#                  mpg  displacement       weight  acceleration    origin
# cylinders
# 4          25.285714    107.000000  2292.571429     16.000000  2.285714
# 6          20.500000    199.000000  2710.500000     15.500000  1.000000
# 8          14.111111    367.555556  3940.055556     11.194444  1.000000

# %%
year_cylinder.loc[(70,4)]
# Out:
# mpg               25.285714
# displacement     107.000000
# weight          2292.571429
# acceleration      16.000000
# origin             2.285714
# Name: (70, 4), dtype: float64

# %%
year_cylinder.xs(key=6, level='cylinders')
# Out:
#                   mpg  displacement       weight  acceleration    origin
# model_year
# 70          20.500000    199.000000  2710.500000     15.500000  1.000000
# 71          18.000000    243.375000  3171.875000     14.750000  1.000000
# 73          19.000000    212.250000  2917.125000     15.687500  1.250000
# 74          17.857143    230.428571  3320.000000     16.857143  1.000000
# 75          17.583333    233.750000  3398.333333     17.708333  1.000000
# 76          20.000000    221.400000  3349.600000     17.000000  1.300000
# 77          19.500000    220.400000  3383.000000     16.900000  1.400000
# 78          19.066667    213.250000  3314.166667     16.391667  1.166667
# 79          22.950000    205.666667  3025.833333     15.433333  1.000000
# 80          25.900000    196.500000  3145.500000     15.050000  2.000000
# 81          23.428571    184.000000  3093.571429     15.442857  1.714286
# 82          28.333333    225.000000  2931.666667     16.033333  1.000000

# %% [markdown]
# df.aggregate(['mean','std'])['mpg']

# %%
df.aggregate({'mpg': ['mean', 'min', 'max'], 'weight': ['std', 'mean']})
# Out:
#             mpg       weight
# max   46.600000          NaN
# mean  23.514573  2970.424623
# min    9.000000          NaN
# std         NaN   846.841774

# %%
registrations = pd.DataFrame({'reg_id':[1,2,3,4],'name':['Andrew','Bobo','Claire','David']})
logins = pd.DataFrame({'log_id':[1,2,3,4],'name':['Xavier','Andrew','Yolanda','Bobo']})

# %%
registrations
# Out:
#    reg_id    name
# 0       1  Andrew
# 1       2    Bobo
# 2       3  Claire
# 3       4   David

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
# help(pd.merge)
pd.merge(registrations, logins, how='inner', on='name')
# Out:
#    reg_id    name  log_id
# 0       1  Andrew       2
# 1       2    Bobo       4

# %%
pd.merge(registrations, logins, how='left', on='name')
# Out:
#    reg_id    name  log_id
# 0       1  Andrew     2.0
# 1       2    Bobo     4.0
# 2       3  Claire     NaN
# 3       4   David     NaN

# %%
pd.merge(registrations, logins, how='right', on='name')
# Out:
#    reg_id     name  log_id
# 0     NaN   Xavier       1
# 1     1.0   Andrew       2
# 2     NaN  Yolanda       3
# 3     2.0     Bobo       4

# %%
pd.merge(registrations, logins, how='outer', on='name')
# Out:
#    reg_id     name  log_id
# 0     1.0   Andrew     2.0
# 1     2.0     Bobo     4.0
# 2     3.0   Claire     NaN
# 3     4.0    David     NaN
# 4     NaN   Xavier     1.0
# 5     NaN  Yolanda     3.0

# %%
from sqlalchemy import create_engine

# %%
temp_db = create_engine('sqlite:///:memory:')

# %%
df = pd.DataFrame(np.random.randint(low=0, high=100, size=(2000,6)), columns=['a','b', 'c', 'd', 'e', 'f'])
df
# Out:
#        a   b   c   d   e   f
# 0     63  86  38  96  67  16
# 1     17  38  49  80  60  71
# 2     21  15   8  56  69  26
# 3     91  63  11  18   1  23
# 4     87  52  16  31   7  64
# ...   ..  ..  ..  ..  ..  ..
# 1995  21  37  86  97  71   5
# 1996  99  24  90  30   0  70
# 1997  61  13  60  25  56  22
# 1998  43  17  80  39  27   7
# 1999  28  38  85  32  26  43
#
# [2000 rows x 6 columns]

# %%
df.to_sql('new_table', temp_db)

# %%
new_df = pd.read_sql(sql='new_table', con=temp_db)
new_df
# Out:
#       index   a   b   c   d   e   f
# 0         0  63  86  38  96  67  16
# 1         1  17  38  49  80  60  71
# 2         2  21  15   8  56  69  26
# 3         3  91  63  11  18   1  23
# 4         4  87  52  16  31   7  64
# ...     ...  ..  ..  ..  ..  ..  ..
# 1995   1995  21  37  86  97  71   5
# 1996   1996  99  24  90  30   0  70
# 1997   1997  61  13  60  25  56  22
# 1998   1998  43  17  80  39  27   7
# 1999   1999  28  38  85  32  26  43
#
# [2000 rows x 7 columns]

# %%
df = pd.read_sql_query(sql='select * from new_table', con=temp_db)
df
# Out:
#       index   a   b   c   d   e   f
# 0         0  63  86  38  96  67  16
# 1         1  17  38  49  80  60  71
# 2         2  21  15   8  56  69  26
# 3         3  91  63  11  18   1  23
# 4         4  87  52  16  31   7  64
# ...     ...  ..  ..  ..  ..  ..  ..
# 1995   1995  21  37  86  97  71   5
# 1996   1996  99  24  90  30   0  70
# 1997   1997  61  13  60  25  56  22
# 1998   1998  43  17  80  39  27   7
# 1999   1999  28  38  85  32  26  43
#
# [2000 rows x 7 columns]
